# %% [markdown]
# # Image Representation in OpenCV (RGBvs BGR)

# %% [markdown]
# ## Dependencies

# %% [markdown]
# Berikut adalah daftar modules dan packages yang perlu kita install untuk dapat mengikuti tutorial ini:
#
# - [OpenCV](https://opencv.org/)
# - [opencv-python](https://pypi.org/project/opencv-python/): ```pip install -U opencv-python```
# - [Matplotlib](https://matplotlib.org/): ```pip install -U matplotlib```

# %% [markdown]
# ## Import Modules

# %% [markdown]
# Berikut adalah beberapa Python modules yang perlu kita import untuk dapat mengikuti tutorial ini.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Global Identifiers

# %% [markdown]
# Dalam tutorial ini terdapat beberapa file foto yang dapat digunakan untuk mempelajari deteksi wajah.

# %%
IMAGE_PATH = './dataset/classroom/03.jpg'
# IMAGE_PATH = './dataset/babies/03.jpg'

# %% [markdown]
# ## Load Image Dataset

# %% [markdown]
# Membuat objek image OpenCV

# %%
bgr_img = cv2.imread(IMAGE_PATH)

# %%
bgr_img.shape
# Out:
# (1024, 1024, 3)

# %%
bgr_img
# Out:
# array([[[ 73, 108, 112],
#         [ 73, 108, 112],
#         [ 74, 109, 113],
#         ...,
#         [101, 128, 132],
#         [ 99, 126, 130],
#         [ 95, 122, 126]],
#
#        [[ 75, 110, 114],
#         [ 75, 110, 114],
#         [ 77, 112, 116],
#         ...,
#         [ 97, 124, 128],
#         [ 96, 123, 127],
#         [ 96, 123, 127]],
#
#        [[ 77, 112, 116],
#         [ 78, 113, 117],
#         [ 80, 115, 119],
#         ...,
#         [ 97, 122, 126],
#         [ 97, 122, 126],
#         [100, 125, 129]],
#
#        ...,
#
#        [[157, 182, 184],
#         [157, 182, 184],
#         [158, 183, 185],
#         ...,
#         [164, 187, 183],
#         [164, 187, 183],
#         [166, 189, 185]],
#
#        [[157, 182, 184],
#         [158, 183, 185],
#         [161, 184, 186],
#         ...,
#         [164, 186, 184],
#         [165, 188, 184],
#         [166, 189, 185]],
#
#        [[157, 182, 184],
#         [159, 184, 186],
#         [162, 185, 187],
#         ...,
#         [164, 186, 184],
#         [165, 188, 184],
#         [167, 190, 186]]], dtype=uint8)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(bgr_img)

# %% [markdown]
# ## RGB Format

# %%
rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(rgb_img)

# %% [markdown]
# ## Gray Scale Image

# %%
gray_img = cv2.cvtColor(src=rgb_img, code=cv2.COLOR_RGB2GRAY)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(gray_img)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(cv2.cvtColor(src=gray_img, code=cv2.COLOR_GRAY2RGB))
